# %% [markdown]
# ## **Módulo 01: Introduccion al diseño de mapas en Python**
# En el desarrollo  de los ejercicios recomiendo utilizar [Visual Studio Code](https://www.youtube.com/watch?v=ZYat1is07VI) para editar el código, a su vez para comprender mejor el contenido es preferible conocer algunos conceptos de programación y Sistemas de Información Geográfica(SIG).
#
# **TEMAS**
#
# *  Lectura de archivos
# *  Visualización de la información
# *  Consultas o querys
# *  Sistema de referencia
# *  Cálculo de área y perímetro
# *  Creación de centroides
# *  Envolvente convexa
# *  Área de influencia
# *  Intersección de geometrías

# %% [markdown]
# **LECTURA DE ARCHIVOS**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
#Importar libreria geopandas
import geopandas as gpd

# %%
#Leer archivo shapefile
ANP_SHP = gpd.read_file(r"D:\Fernando\CURSOS\Python dumnnies\data\ANP\ANPNacionalDefinitivas.shp")
ANP_SHP
# Out:
#     objectid_1  anp_gid anp_codi              anp_cate  \
# 0         3286        1     BP01  Bosque de Protección
# 1         3287        2     BP02  Bosque de Protección
# 2         3288        3     BP03  Bosque de Protección
# 3         3289        4     BP04  Bosque de Protección
# 4         3290        5     BP05  Bosque de Protección
# ..         ...      ...      ...                   ...
# 93        3401       94     SN07    Santuario Nacional
# 94        3405       95     SN08    Santuario Nacional
# 95        3407       96     SN09    Santuario Nacional
# 96        4428      345     RN16      Reserva Nacional
# 97        7229      356     RN17      Reserva Nacional
#
#                                           anp_nomb anp_sect     anp_ubpo  \
# 0   Aledaño a la Bocatoma del Canal Nuevo Imperial     None         Lima
# 1                                Puquio Santa Rosa     None  La Libertad
# 2                                       de Pui Pui     None        Junín
# ...

# %%
#Leer el archivo zip 
COMUNIDADES = gpd.read_file(r"D:\Fernando\CURSOS\Python dumnnies\data\humedales_ramsar.zip")
COMUNIDADES

# %%
#Leer el archivo gml 
manzanas_gml = gpd.read_file(r"C:\Users\JuanMa\Documents\JuanMa\Dev\AnacondaProjects\GeoPandas\Datos\CentroidesManzas.xml.gml")
manzanas_gml

# %%
#Leer el archivo geojson
localidades_geojson = gpd.read_file(r"C:\Users\JuanMa\Documents\JuanMa\Dev\AnacondaProjects\GeoPandas\Datos\Localidades.geojson")
localidades_geojson

# %% [markdown]
# Al finalizar esta sección quizás puedan ocurrir algunas preguntas como:
# * ¿Dónde puedo encontrar más elementos vectoriales como shapefile, geojson u otros?
# * ¿Que formato es mejor utilizar para el almacenamiento de mis datos?
# * ¿Cuál es la diferencia de utilizar Geopandas con un Sistema de Información Geográfica como ArcGIS o QGIS?
# * ¿Porqué recomiendas utilizar Visual Studio Code para el desarrollo de los ejercicios?
# * ¿Cómo instalo Visual Studio Code?¿Existen otras alternativas?
#
# Si deseas obtener apoyo puedes escribirme a mi correo y agendaremos una reunión 😃
#
# mariocaceresreyna25@gmail.com 📧
# Asunto: Asesoría académica

# %% [markdown]
# **VISUALIZACIÓN DE INFORMACIÓN**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
ANP = ANP_SHP.set_index("anp_nomb")
ANP
# Out:
#                                                 objectid_1  anp_gid anp_codi  \
# anp_nomb
# Aledaño a la Bocatoma del Canal Nuevo Imperial        3286        1     BP01
# Puquio Santa Rosa                                     3287        2     BP02
# de Pui Pui                                            3288        3     BP03
# San Matias-San Carlos                                 3289        4     BP04
# de Pagaibamba                                         3290        5     BP05
# ...                                                    ...      ...      ...
# Pampa Hermosa                                         3401       94     SN07
# Tabaconas-Namballe                                    3405       95     SN08
# Cordillera de Colán                                   3407       96     SN09
# Dorsal de Nasca                                       4428      345     RN16
# Illescas                                              7229      356     RN17
#
# ...

# %%
ANP.head(3)
# Out:
#                                                 objectid_1  anp_gid anp_codi  \
# anp_nomb
# Aledaño a la Bocatoma del Canal Nuevo Imperial        3286        1     BP01
# Puquio Santa Rosa                                     3287        2     BP02
# de Pui Pui                                            3288        3     BP03
#
#                                                             anp_cate anp_sect  \
# anp_nomb
# Aledaño a la Bocatoma del Canal Nuevo Imperial  Bosque de Protección     None
# Puquio Santa Rosa                               Bosque de Protección     None
# de Pui Pui                                      Bosque de Protección     None
#
#                                                    anp_ubpo  anp_suleg  \
# anp_nomb
# Aledaño a la Bocatoma del Canal Nuevo Imperial         Lima      18.11
# Puquio Santa Rosa                               La Libertad      72.50
# de Pui Pui                                            Junín   60000.00
#
# ...

# %%
ANP.tail(4)
# Out:
#                      objectid_1  anp_gid anp_codi            anp_cate  \
# anp_nomb
# Tabaconas-Namballe         3405       95     SN08  Santuario Nacional
# Cordillera de Colán        3407       96     SN09  Santuario Nacional
# Dorsal de Nasca            4428      345     RN16    Reserva Nacional
# Illescas                   7229      356     RN17    Reserva Nacional
#
#                     anp_sect   anp_ubpo   anp_suleg  \
# anp_nomb
# Tabaconas-Namballe      None  Cajamarca    32124.87
# Cordillera de Colán     None   Amazonas    39215.80
# Dorsal de Nasca         None       None  6239205.75
# Illescas                None      Piura    36550.70
#
#                                                               anp_uicn  \
# anp_nomb
# Tabaconas-Namballe   III - Conservación de características naturale...
# Cordillera de Colán  III - Conservación de características naturale...
# Dorsal de Nasca              VI - Uso sostenible de recursos naturales
# ...

# %% [markdown]
# **CONSULTAS O QUERYS**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson

# %% [markdown]
# ¿Que Áreas Naturales Protegidas le corresponden a una región?
# ¿Cuáles son las ANP que corresponden a Bosque de protección?
# ¿Cuál es la categoría del ANP Paigabamba? y ¿Cuál es la región a la que corresponde?
# ¿Que ANP corresponden al sector sur?

# %%
#¿Cuáles son las Áreas Naturales Protegidas del departamento de Cajamarca?
ANP_Dep = ANP.query("anp_ubpo == 'Cajamarca'")
ANP_Dep
# Out:
#                            objectid_1  anp_gid anp_codi  \
# anp_nomb
# de Pagaibamba                    3290        5     BP05
# de Cutervo                       3297        9     PN01
# de Cutervo                       3298       10     PN01
# Bosques Nublados de Udima        3367       82    RVS03
# Bosques Nublados de Udima        3370       81    RVS03
# Bosques Nublados de Udima        3373       83    RVS03
# Tabaconas-Namballe               3405       95     SN08
#
#                                             anp_cate       anp_sect  \
# anp_nomb
# de Pagaibamba                   Bosque de Protección           None
# de Cutervo                           Parque Nacional   Sector Norte
# de Cutervo                           Parque Nacional     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre  Sector Centro
# Bosques Nublados de Udima  Refugio de Vida Silvestre   Sector Norte
# ...

# %%
#Método de pandas que realiza la extracción de una etiqueta
ANP = ANP.set_geometry("geometry")
Tabaconas = ANP.loc["Tabaconas-Namballe", "geometry"]
Tabaconas

# %%
Udima = ANP.query("anp_nomb == 'Bosques Nublados de Udima'")
Udima
# Out:
#                            objectid_1  anp_gid anp_codi  \
# anp_nomb
# Bosques Nublados de Udima        3367       82    RVS03
# Bosques Nublados de Udima        3370       81    RVS03
# Bosques Nublados de Udima        3373       83    RVS03
#
#                                             anp_cate       anp_sect  \
# anp_nomb
# Bosques Nublados de Udima  Refugio de Vida Silvestre     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre  Sector Centro
# Bosques Nublados de Udima  Refugio de Vida Silvestre   Sector Norte
#
#                             anp_ubpo  anp_suleg  \
# anp_nomb
# Bosques Nublados de Udima  Cajamarca    9849.64
# Bosques Nublados de Udima  Cajamarca      74.41
# Bosques Nublados de Udima  Cajamarca    2259.15
#
#                                                                     anp_uicn  \
# anp_nomb
# Bosques Nublados de Udima  IV - Conservar el hábitat por intervención con...
# ...

# %% [markdown]
# **SISTEMA DE REFERENCIA**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
#¿Cuál es el sistema de referencia del elemento?
ANP_Dep.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Definir geometria 
ANP_Dep = ANP_Dep.set_geometry("geometry")

# %%
#¿Cómo definir un nuevo sistema de referencia de coordenadas?
ANP_SRC = ANP_Dep.to_crs("EPSG:32717")

# %%
#Revisa el nuevo sistema de referencia 😉
ANP_SRC.crs
# Out:
# <Projected CRS: EPSG:32717>
# Name: WGS 84 / UTM zone 17S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 84°W to 78°W - by country
# - bounds: (-84.0, -80.0, -78.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 17S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Al finalizar esta sección quizás puedan ocurrir algunas preguntas como:
# * ¿Cómo encuentro el sistema de referencia para mi área de estudio?
# * ¿Cómo puedo realizar consultas en la cuales realice la selección para dos campos?
# * ¿Porqué es necesario definir un nuevo Sistema de referencia de coordenadas?
# * ¿Que son los códigos EPSG?
# * ¿Que es un Datum?
# * ¿Cómo se construye un Sistema de referencia de coordenadas?
# * ¿Cuantos sistemas de referencias de coordenadas existen en mi país?
#
# Si deseas obtener apoyo puedes escribirme a mi correo y agendaremos una reunión 😃
#
# mariocaceresreyna25@gmail.com 📧
# Asunto: Asesoría académica

# %% [markdown]
# **CÁLCULO DE ÁREA Y PERÍMETRO**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
#Calcular el área
ANP_SRC["area"] = ANP_SRC.area
ANP_SRC["area"]
# Out:
# anp_nomb
# de Pagaibamba                2.078380e+07
# de Cutervo                   2.429540e+07
# de Cutervo                   5.784690e+07
# Bosques Nublados de Udima    9.849638e+07
# Bosques Nublados de Udima    7.440711e+05
# Bosques Nublados de Udima    2.259154e+07
# Tabaconas-Namballe           3.212487e+08
# Name: area, dtype: float64

# %%
#Calcular el perímetro 
ANP_SRC["perimetro"] = ANP_SRC.boundary
ANP_SRC
# Out:
#                            objectid_1  anp_gid anp_codi  \
# anp_nomb
# de Pagaibamba                    3290        5     BP05
# de Cutervo                       3297        9     PN01
# de Cutervo                       3298       10     PN01
# Bosques Nublados de Udima        3367       82    RVS03
# Bosques Nublados de Udima        3370       81    RVS03
# Bosques Nublados de Udima        3373       83    RVS03
# Tabaconas-Namballe               3405       95     SN08
#
#                                             anp_cate       anp_sect  \
# anp_nomb
# de Pagaibamba                   Bosque de Protección           None
# de Cutervo                           Parque Nacional   Sector Norte
# de Cutervo                           Parque Nacional     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre  Sector Centro
# Bosques Nublados de Udima  Refugio de Vida Silvestre   Sector Norte
# ...

# %% [markdown]
# **CREACIÓN DE CENTROIDES**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
ANP_SRC["centroide"] = ANP_SRC.centroid
ANP_SRC
# Out:
#                            objectid_1  anp_gid anp_codi  \
# anp_nomb
# de Pagaibamba                    3290        5     BP05
# de Cutervo                       3297        9     PN01
# de Cutervo                       3298       10     PN01
# Bosques Nublados de Udima        3367       82    RVS03
# Bosques Nublados de Udima        3370       81    RVS03
# Bosques Nublados de Udima        3373       83    RVS03
# Tabaconas-Namballe               3405       95     SN08
#
#                                             anp_cate       anp_sect  \
# anp_nomb
# de Pagaibamba                   Bosque de Protección           None
# de Cutervo                           Parque Nacional   Sector Norte
# de Cutervo                           Parque Nacional     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre  Sector Centro
# Bosques Nublados de Udima  Refugio de Vida Silvestre   Sector Norte
# ...

# %%
punto_inicial = ANP_SRC["centroide"].iloc[0]

# %%
punto_inicial

# %%
ANP_SRC["distancia"] = ANP_SRC["centroide"].distance(punto_inicial)
ANP_SRC["distancia"]
# Out:
# anp_nomb
# de Pagaibamba                     0.000000
# de Cutervo                    42403.963243
# de Cutervo                    34895.477445
# Bosques Nublados de Udima     48682.807129
# Bosques Nublados de Udima     40659.049829
# Bosques Nublados de Udima     29265.223277
# Tabaconas-Namballe           138339.292247
# Name: distancia, dtype: float64

# %%
ANP_SRC["distancia"].mean()
# Out:
# 47749.40188137482

# %%
ANP_SRC.plot("area", legend = True)
# Out:
# <AxesSubplot:>

# %%
ANP_SRC = ANP_SRC.set_geometry("centroide")

# %%
ANP_SRC.plot("area", legend = True)
# Out:
# <AxesSubplot:>

# %%
#Colocar ambos gráficos
axis = ANP_SRC["geometry"].plot()
ANP_SRC["centroide"].plot(ax = axis, color = "black")
# Out:
# <AxesSubplot:>

# %%
ANP_SRC = ANP_SRC.set_geometry("geometry")
ANP_SRC.plot(column = "anp_cate", legend = True, legend_kwds = {"loc": "upper right"}, figsize = (20, 12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **ENVOLVENTE CONVEXA**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
ANP_SRC["envolvente"] = ANP_SRC.convex_hull

# %%
axis = ANP_SRC["envolvente"].plot(alpha = 0.5)
ANP_SRC["perimetro"].plot(ax = axis, color = "red", linewidth = 0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **ÁREA DE INFLUENCIA**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
ANP_SRC["buffer"] = ANP_SRC.buffer(10000)

# %%
ANP_SRC["buffer_centroide"] = ANP_SRC["centroide"].buffer(10000)

# %%
axis = ANP_SRC["buffer"].plot(alpha = 0.5)
ANP_SRC["buffer_centroide"].plot(ax = axis, color = "red", alpha = 0.5)
ANP_SRC["perimetro"].plot(ax = axis, color = "white", linewidth = 0.5)
# Out:
# <AxesSubplot:>

# %%
#Método de pandas que realiza la extracción de una etiqueta
ANP_SRC = ANP_SRC.set_geometry("geometry")
Tabaconas = ANP_SRC.loc["Tabaconas-Namballe", "geometry"]
Tabaconas

# %%
Udima = ANP_SRC.query("anp_nomb == 'Bosques Nublados de Udima'")
Udima
# Out:
#                            objectid_1  anp_gid anp_codi  \
# anp_nomb
# Bosques Nublados de Udima        3367       82    RVS03
# Bosques Nublados de Udima        3370       81    RVS03
# Bosques Nublados de Udima        3373       83    RVS03
#
#                                             anp_cate       anp_sect  \
# anp_nomb
# Bosques Nublados de Udima  Refugio de Vida Silvestre     Sector Sur
# Bosques Nublados de Udima  Refugio de Vida Silvestre  Sector Centro
# Bosques Nublados de Udima  Refugio de Vida Silvestre   Sector Norte
#
#                             anp_ubpo  anp_suleg  \
# anp_nomb
# Bosques Nublados de Udima  Cajamarca    9849.64
# Bosques Nublados de Udima  Cajamarca      74.41
# Bosques Nublados de Udima  Cajamarca    2259.15
#
#                                                                     anp_uicn  \
# anp_nomb
# Bosques Nublados de Udima  IV - Conservar el hábitat por intervención con...
# ...

# %%
Udima.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **INTERSECCIÓN DE GEOMETRÍAS**
#
# Existe variedad de formatos que pueden ser utilizados para representar los elementos geoespaciales ya sea puntos, líneas y polígonos. Geopandas permite la lectura de datos espaciales vectoriales en formatos como shapefile, geojson y geopackage.

# %%
ANP_SRC["buffer"].intersects(Tabaconas)
# Out:
# anp_nomb
# de Pagaibamba                False
# de Cutervo                   False
# de Cutervo                   False
# Bosques Nublados de Udima    False
# Bosques Nublados de Udima    False
# Bosques Nublados de Udima    False
# Tabaconas-Namballe            True
# dtype: bool
